# %%
import pandas as pd

# %%
dados = pd.read_csv('insect.csv')
dados.shape
# Out:
# (72, 2)

# %%
dados
# Out:
#     count spray
# 0      10     A
# 1       7     A
# 2      20     A
# 3      14     A
# 4      14     A
# ..    ...   ...
# 67     10     F
# 68     26     F
# 69     26     F
# 70     24     F
# 71     13     F
#
# [72 rows x 2 columns]

# %%
agrupar = dados.groupby(['spray'])['count'].sum()
agrupar
# Out:
# spray
# A    174
# B    184
# C     25
# D     59
# E     42
# F    200
# Name: count, dtype: int64

# %%
gráfico de barras
agrupar.plot.bar()
# Out:
# <Axes: xlabel='spray'>

# %%
## gráfico de pizza - setor
agrupar.plot.pie()
# Out:
# <Axes: ylabel='count'>

# %%
## gráfico com Legenda
agrupar.plot.pie(legend = True)
# Out:
# <Axes: ylabel='count'>
