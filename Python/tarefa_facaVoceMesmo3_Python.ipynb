# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as srn

# %%
dados = pd.read_csv('dados.csv', sep=';')
dados.head()
# Out:
#    CODIGO               MUNICIPIO       PIB  VALOREMPENHO
# 0     106   SANTANA DO LIVRAMENTO  12240.76    1088666.10
# 1     113            SANTO ANGELO  16575.82     800669.92
# 2     118  SAO FRANCISCO DE ASSIS  12037.61     466122.80
# 3      13         CACAPAVA DO SUL  13674.54     485535.86
# 4     120             SAO GABRIEL  19912.38     533719.86

# %%
srn.histplot(dados.PIB, bins=10)
# Out:
# <Axes: xlabel='PIB', ylabel='Count'>

# %%
srn.histplot(dados.VALOREMPENHO, bins = 10)
# Out:
# <Axes: xlabel='VALOREMPENHO', ylabel='Count'>

# %%
agrupar = dados.sort_values('PIB').head(10)
agrupar = agrupar.iloc[:,1:3]
agrupar.plot.bar(x='MUNICIPIO', y = 'PIB')
# Out:
# <Axes: xlabel='MUNICIPIO'>

# %%
agruparValor = dados.sort_values('VALOREMPENHO').head(10)
agruparValor = agruparValor.iloc[:,[1,3]]
agruparValor.plot.bar()
# Out:
# <Axes: >
